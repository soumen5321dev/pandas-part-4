# %%
print ("I want to become a data scientist")
# Out:
# I want to become a data scientist

# %%
print ("I want to become a data scientist")
# Out:
# I want to become a data scientist

# %%
print ("I want to become a data scientist")
# Out:
# I want to become a data scientist

# %%
print ("Yes really i can because god and my family is always with me")
# Out:
# Yes really i can because god and my family is always with me

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop("PassengerId", axis = 1, inplace=True)

# %%
df.drop(3, inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index("Name", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.set_index("Name", inplace=True)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:6009, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6006                 missing.append(col)
#    6008 if missing:
# -> 6009     raise KeyError(f"None of {missing} are in the columns")
#    6011 if inplace:
# ...

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d = {'key1' : [3,4,5,6,7],
     'key2' : [5,6,7,8,6],
     'key3' : [4,5,6,7,8]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     5     4
# 1     4     6     5
# 2     5     7     6
# 3     6     8     7
# 4     7     6     8

# %%
df1 = pd.read_csv("Sample Data1.csv")

# %%
df1
# Out:
#    Emp ID           Last      First             Full Name  \
# 0   E1180         Bacata     Stevie          StevieBacata
# 1   E1110          BARRY       Adam             AdamBARRY
# 2   E1232          Betts     Connor           ConnorBetts
# 3   E1243       martinez     carlos        carlosmartinez
# 4   E1248           Biti     Yvette            YvetteBiti
# 5   E1227         BOLLER        Jim             JimBOLLER
# 6   E1230            Bui    Charlie            CharlieBui
# 7   E1162        Carlton    Barbara        BarbaraCarlton
# 8   E1001          CAROL        Joe              JoeCAROL
# 9   E1224        CHAFFEE        Jim            JimCHAFFEE
# 10  E1203         Chairs   Samantha        SamanthaChairs
# 11  E1211        CHAUDRI        Uma            UmaCHAUDRI
# 12  E1198            CHU  Elizabeth          ElizabethCHU
# 13  E1003          CHUNG       Eric             EricCHUNG
# 14  E1253          CLARK  elizabeth        elizabethCLARK
# ...

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#    Emp ID           Last      First             Full Name  \
# 0   E1180         Bacata     Stevie          StevieBacata
# 1   E1110          BARRY       Adam             AdamBARRY
# 2   E1232          Betts     Connor           ConnorBetts
# 3   E1243       martinez     carlos        carlosmartinez
# 4   E1248           Biti     Yvette            YvetteBiti
# 6   E1230            Bui    Charlie            CharlieBui
# 7   E1162        Carlton    Barbara        BarbaraCarlton
# 8   E1001          CAROL        Joe              JoeCAROL
# 9   E1224        CHAFFEE        Jim            JimCHAFFEE
# 11  E1211        CHAUDRI        Uma            UmaCHAUDRI
# 12  E1198            CHU  Elizabeth          ElizabethCHU
# 13  E1003          CHUNG       Eric             EricCHUNG
# 14  E1253          CLARK  elizabeth        elizabethCLARK
# 15  E1235          CLARK       ANNA             ANNACLARK
# 16  E1221           COLE    Sabrina           SabrinaCOLE
# ...

# %%
df1.dropna(axis=1)
# Out:
#    Emp ID           Last      First             Full Name  \
# 0   E1180         Bacata     Stevie          StevieBacata
# 1   E1110          BARRY       Adam             AdamBARRY
# 2   E1232          Betts     Connor           ConnorBetts
# 3   E1243       martinez     carlos        carlosmartinez
# 4   E1248           Biti     Yvette            YvetteBiti
# 6   E1230            Bui    Charlie            CharlieBui
# 7   E1162        Carlton    Barbara        BarbaraCarlton
# 8   E1001          CAROL        Joe              JoeCAROL
# 9   E1224        CHAFFEE        Jim            JimCHAFFEE
# 11  E1211        CHAUDRI        Uma            UmaCHAUDRI
# 12  E1198            CHU  Elizabeth          ElizabethCHU
# 13  E1003          CHUNG       Eric             EricCHUNG
# 14  E1253          CLARK  elizabeth        elizabethCLARK
# 15  E1235          CLARK       ANNA             ANNACLARK
# 16  E1221           COLE    Sabrina           SabrinaCOLE
# ...

# %%
df2 = pd.read_csv("Sample Data1.csv")

# %%
df2
# Out:
#    Emp ID           Last      First             Full Name  \
# 0   E1180         Bacata     Stevie          StevieBacata
# 1   E1110          BARRY       Adam             AdamBARRY
# 2   E1232          Betts     Connor           ConnorBetts
# 3   E1243       martinez     carlos        carlosmartinez
# 4   E1248           Biti     Yvette            YvetteBiti
# 5   E1227         BOLLER        Jim             JimBOLLER
# 6   E1230            Bui    Charlie            CharlieBui
# 7   E1162        Carlton    Barbara        BarbaraCarlton
# 8   E1001          CAROL        Joe              JoeCAROL
# 9   E1224        CHAFFEE        Jim            JimCHAFFEE
# 10  E1203         Chairs   Samantha        SamanthaChairs
# 11  E1211        CHAUDRI        Uma            UmaCHAUDRI
# 12  E1198            CHU  Elizabeth          ElizabethCHU
# 13  E1003          CHUNG       Eric             EricCHUNG
# 14  E1253          CLARK  elizabeth        elizabethCLARK
# ...

# %%
df2.dropna(axis=1, inplace=True)

# %%
df2
# Out:
#    Emp ID           Last      First             Full Name  \
# 0   E1180         Bacata     Stevie          StevieBacata
# 1   E1110          BARRY       Adam             AdamBARRY
# 2   E1232          Betts     Connor           ConnorBetts
# 3   E1243       martinez     carlos        carlosmartinez
# 4   E1248           Biti     Yvette            YvetteBiti
# 5   E1227         BOLLER        Jim             JimBOLLER
# 6   E1230            Bui    Charlie            CharlieBui
# 7   E1162        Carlton    Barbara        BarbaraCarlton
# 8   E1001          CAROL        Joe              JoeCAROL
# 9   E1224        CHAFFEE        Jim            JimCHAFFEE
# 10  E1203         Chairs   Samantha        SamanthaChairs
# 11  E1211        CHAUDRI        Uma            UmaCHAUDRI
# 12  E1198            CHU  Elizabeth          ElizabethCHU
# 13  E1003          CHUNG       Eric             EricCHUNG
# 14  E1253          CLARK  elizabeth        elizabethCLARK
# ...

# %%
df2
# Out:
#    Emp ID           Last      First             Full Name  \
# 0   E1180         Bacata     Stevie          StevieBacata
# 1   E1110          BARRY       Adam             AdamBARRY
# 2   E1232          Betts     Connor           ConnorBetts
# 3   E1243       martinez     carlos        carlosmartinez
# 4   E1248           Biti     Yvette            YvetteBiti
# 5   E1227         BOLLER        Jim             JimBOLLER
# 6   E1230            Bui    Charlie            CharlieBui
# 7   E1162        Carlton    Barbara        BarbaraCarlton
# 8   E1001          CAROL        Joe              JoeCAROL
# 9   E1224        CHAFFEE        Jim            JimCHAFFEE
# 10  E1203         Chairs   Samantha        SamanthaChairs
# 11  E1211        CHAUDRI        Uma            UmaCHAUDRI
# 12  E1198            CHU  Elizabeth          ElizabethCHU
# 13  E1003          CHUNG       Eric             EricCHUNG
# 14  E1253          CLARK  elizabeth        elizabethCLARK
# ...

# %%
df3 = pd.read_csv("Sample Data1.csv")

# %%
df3
# Out:
#    Emp ID           Last      First             Full Name  \
# 0   E1180         Bacata     Stevie          StevieBacata
# 1   E1110          BARRY       Adam             AdamBARRY
# 2   E1232          Betts     Connor           ConnorBetts
# 3   E1243       martinez     carlos        carlosmartinez
# 4   E1248           Biti     Yvette            YvetteBiti
# 5   E1227         BOLLER        Jim             JimBOLLER
# 6   E1230            Bui    Charlie            CharlieBui
# 7   E1162        Carlton    Barbara        BarbaraCarlton
# 8   E1001          CAROL        Joe              JoeCAROL
# 9   E1224        CHAFFEE        Jim            JimCHAFFEE
# 10  E1203         Chairs   Samantha        SamanthaChairs
# 11  E1211        CHAUDRI        Uma            UmaCHAUDRI
# 12  E1198            CHU  Elizabeth          ElizabethCHU
# 13  E1003          CHUNG       Eric             EricCHUNG
# 14  E1253          CLARK  elizabeth        elizabethCLARK
# ...

# %%
df3.fillna("soumen")
# Out:
#    Emp ID           Last      First             Full Name  \
# 0   E1180         Bacata     Stevie          StevieBacata
# 1   E1110          BARRY       Adam             AdamBARRY
# 2   E1232          Betts     Connor           ConnorBetts
# 3   E1243       martinez     carlos        carlosmartinez
# 4   E1248           Biti     Yvette            YvetteBiti
# 5   E1227         BOLLER        Jim             JimBOLLER
# 6   E1230            Bui    Charlie            CharlieBui
# 7   E1162        Carlton    Barbara        BarbaraCarlton
# 8   E1001          CAROL        Joe              JoeCAROL
# 9   E1224        CHAFFEE        Jim            JimCHAFFEE
# 10  E1203         Chairs   Samantha        SamanthaChairs
# 11  E1211        CHAUDRI        Uma            UmaCHAUDRI
# 12  E1198            CHU  Elizabeth          ElizabethCHU
# 13  E1003          CHUNG       Eric             EricCHUNG
# 14  E1253          CLARK  elizabeth        elizabethCLARK
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
g = df.groupby("Survived")

# %%
g

# %%
g.sum()
# Out:
# /tmp/ipykernel_110/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            666   8184.67    161    159  16498.1294

# %%
g.mean()
# Out:
# /tmp/ipykernel_110/2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.953079  28.320657  0.472141  0.466276  48.381611

# %%
g1 = df.groupby('Pclass')

# %%
g1.sum()
# Out:
# /tmp/ipykernel_110/2725926089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            135  7076.42     89     77  18124.3125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
g1.mean()
# Out:
# /tmp/ipykernel_110/3287460031.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g1.mean()
#         Survived        Age     SibSp     Parch       Fare
# Pclass
# 1       0.627907  38.250919  0.413953  0.358140  84.299128
# 2       0.472826  29.877630  0.402174  0.380435  20.662183
# 3       0.242363  25.140620  0.615071  0.393075  13.675550

# %%
g1.max()
# Out:
# /tmp/ipykernel_110/130714741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()
#                                Name  Survived   Sex   Age  SibSp  Parch  \
# Pclass
# 1          Young, Miss. Marie Grice         1  male  80.0      3      4
# 2         del Carlo, Mr. Sebastiano         1  male  70.0      3      3
# 3       van Melkebeke, Mr. Philemon         1  male  74.0      8      6
#
#             Ticket      Fare
# Pclass
# 1        WE/P 5735  512.3292
# 2        W/C 14208   73.5000
# 3       W./C. 6609   69.5500

# %%
g1.max()['Fare']
# Out:
# /tmp/ipykernel_110/730728694.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max()['Fare']
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.max().T
# Out:
# /tmp/ipykernel_110/2755232466.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().T
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# ...

# %%
g1.max().transpose()
# Out:
# /tmp/ipykernel_110/3907411846.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g1.max().transpose()
# Pclass                           1                          2  \
# Name      Young, Miss. Marie Grice  del Carlo, Mr. Sebastiano
# Survived                         1                          1
# Sex                           male                       male
# Age                           80.0                       70.0
# SibSp                            3                          3
# Parch                            4                          3
# Ticket                   WE/P 5735                  W/C 14208
# Fare                      512.3292                       73.5
#
# Pclass                              3
# Name      van Melkebeke, Mr. Philemon
# Survived                            1
# ...
